# %%
import numpy as np
import pandas as pd
import os
import gzip
import io
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# vibo: читаем предобработанный лог (index_col=0 считываем индексы тоже)
data_logs = pd.read_csv('/content/drive/MyDrive/minecraft/logs.csv', index_col=0)

# %% [markdown]
# # 5. Анализ действий пользователя

# %%
data_logs
# Out:
#              date      time        serv_teg_inf serv_teg  \
# 0     2023-02-13   21:31:47          ServerMain     INFO
# 1     2023-02-13   21:31:48          ServerMain    ERROR
# 2     2023-02-13   21:31:48          ServerMain     WARN
# 3     2023-02-13   21:31:48          ServerMain     INFO
# 5     2023-02-13   21:34:03          ServerMain     INFO
# ...           ...       ...                 ...      ...
# 6577  2023-03-09   18:50:50  User Authenticator     INFO
# 6578  2023-03-09   18:50:50       Server thread     INFO
# 6579  2023-03-09   18:50:50       Server thread     INFO
# 6580  2023-03-09   18:52:31       Server thread     INFO
# 6581  2023-03-09   18:57:52       Server thread     INFO
#
#                                               serv_mess  \
# 0                        Building unoptimized datafixer
# 1      Failed to load properties from file: server.p...
# 2                               Failed to load eula.txt
# 3      You need to agree to the EULA in order to run...
# 5                        Building unoptimized datafixer
# ...                                                 ...
# 6577   UUID of player ARTEXX is ee86a614-d39f-3a50-a...
# 6578                             ARTEXX joined the game
# 6579                           ARTEXX[/[0:0:0:0:0:0:0:1
# 6580             ARTEXX issued server command: /farwand
# 6581               ARTEXX issued server command: //wand
#
#       user_authenticator_number  worker_main_number  async_chat_thread_number  \
# 0                           NaN                 NaN                       NaN
# 1                           NaN                 NaN                       NaN
# 2                           NaN                 NaN                       NaN
# 3                           NaN                 NaN                       NaN
# 5                           NaN                 NaN                       NaN
# ...                         ...                 ...                       ...
# 6577                        5.0                 NaN                       NaN
# 6578                        NaN                 NaN                       NaN
# 6579                        NaN                 NaN                       NaN
# 6580                        NaN                 NaN                       NaN
# 6581                        NaN                 NaN                       NaN
#
#      plug_name plug_mess
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN       NaN
# 5          NaN       NaN
# ...        ...       ...
# 6577       NaN       NaN
# 6578       NaN       NaN
# 6579       NaN       NaN
# 6580       NaN       NaN
# 6581       NaN       NaN
#
# [6544 rows x 10 columns]

# %%
# vibo: сводная статистика
data_logs[['date', 'time', 'serv_teg_inf', 'serv_teg', 'serv_mess', 'plug_name', 'plug_mess']].describe()
# Out:
#                date      time   serv_teg_inf serv_teg  \
# count          6544      6544           6544     6544
# unique           10      1306              6        3
# top     2023-03-06   21:13:39  Server thread     INFO
# freq           1093       115           5444     6392
#
#                         serv_mess  plug_name plug_mess
# count                        6092        452       441
# unique                        913          3        50
# top      Preparing spawn area: 0%  WorldEdit
# freq                          674        218        44

# %% [markdown]
# Делаем новый датафрейм с которым будем работать

# %%
summary = data_logs[['date',	'time', 'serv_teg_inf', 'serv_teg', 'serv_mess', 'user_authenticator_number', 'worker_main_number', 'async_chat_thread_number']]
summary
# Out:
#              date      time        serv_teg_inf serv_teg  \
# 0     2023-02-13   21:31:47          ServerMain     INFO
# 1     2023-02-13   21:31:48          ServerMain    ERROR
# 2     2023-02-13   21:31:48          ServerMain     WARN
# 3     2023-02-13   21:31:48          ServerMain     INFO
# 5     2023-02-13   21:34:03          ServerMain     INFO
# ...           ...       ...                 ...      ...
# 6577  2023-03-09   18:50:50  User Authenticator     INFO
# 6578  2023-03-09   18:50:50       Server thread     INFO
# 6579  2023-03-09   18:50:50       Server thread     INFO
# 6580  2023-03-09   18:52:31       Server thread     INFO
# 6581  2023-03-09   18:57:52       Server thread     INFO
#
#                                               serv_mess  \
# 0                        Building unoptimized datafixer
# 1      Failed to load properties from file: server.p...
# 2                               Failed to load eula.txt
# 3      You need to agree to the EULA in order to run...
# 5                        Building unoptimized datafixer
# ...                                                 ...
# 6577   UUID of player ARTEXX is ee86a614-d39f-3a50-a...
# 6578                             ARTEXX joined the game
# 6579                           ARTEXX[/[0:0:0:0:0:0:0:1
# 6580             ARTEXX issued server command: /farwand
# 6581               ARTEXX issued server command: //wand
#
#       user_authenticator_number  worker_main_number  async_chat_thread_number
# 0                           NaN                 NaN                       NaN
# 1                           NaN                 NaN                       NaN
# 2                           NaN                 NaN                       NaN
# 3                           NaN                 NaN                       NaN
# 5                           NaN                 NaN                       NaN
# ...                         ...                 ...                       ...
# 6577                        5.0                 NaN                       NaN
# 6578                        NaN                 NaN                       NaN
# 6579                        NaN                 NaN                       NaN
# 6580                        NaN                 NaN                       NaN
# 6581                        NaN                 NaN                       NaN
#
# [6544 rows x 8 columns]

# %%
summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6544 entries, 0 to 6581
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       6544 non-null   object
#  1   time                       6544 non-null   object
#  2   serv_teg_inf               6544 non-null   object
#  3   serv_teg                   6544 non-null   object
#  4   serv_mess                  6092 non-null   object
#  5   user_authenticator_number  93 non-null     float64
#  6   worker_main_number         891 non-null    float64
#  7   async_chat_thread_number   19 non-null     float64
# dtypes: float64(3), object(5)
# memory usage: 460.1+ KB

# %%
# vibo: удаляем лишнее как и в блоке с анализом заголовков сообщений сервера
# плагин WorldGuard выдает свой тег в сообщения сервера отдельной группой 
summary = summary[summary['serv_teg_inf'] != 'WorldGuard Region I/O']
# vibo: ищем не нулевые строки
find_index = summary['serv_mess'].dropna().index
# vibo: фильтруем по ним датафрейм
summary = summary[summary.index.isin(find_index)]
summary
# Out:
#              date      time        serv_teg_inf serv_teg  \
# 0     2023-02-13   21:31:47          ServerMain     INFO
# 1     2023-02-13   21:31:48          ServerMain    ERROR
# 2     2023-02-13   21:31:48          ServerMain     WARN
# 3     2023-02-13   21:31:48          ServerMain     INFO
# 5     2023-02-13   21:34:03          ServerMain     INFO
# ...           ...       ...                 ...      ...
# 6577  2023-03-09   18:50:50  User Authenticator     INFO
# 6578  2023-03-09   18:50:50       Server thread     INFO
# 6579  2023-03-09   18:50:50       Server thread     INFO
# 6580  2023-03-09   18:52:31       Server thread     INFO
# 6581  2023-03-09   18:57:52       Server thread     INFO
#
#                                               serv_mess  \
# 0                        Building unoptimized datafixer
# 1      Failed to load properties from file: server.p...
# 2                               Failed to load eula.txt
# 3      You need to agree to the EULA in order to run...
# 5                        Building unoptimized datafixer
# ...                                                 ...
# 6577   UUID of player ARTEXX is ee86a614-d39f-3a50-a...
# 6578                             ARTEXX joined the game
# 6579                           ARTEXX[/[0:0:0:0:0:0:0:1
# 6580             ARTEXX issued server command: /farwand
# 6581               ARTEXX issued server command: //wand
#
#       user_authenticator_number  worker_main_number  async_chat_thread_number
# 0                           NaN                 NaN                       NaN
# 1                           NaN                 NaN                       NaN
# 2                           NaN                 NaN                       NaN
# 3                           NaN                 NaN                       NaN
# 5                           NaN                 NaN                       NaN
# ...                         ...                 ...                       ...
# 6577                        5.0                 NaN                       NaN
# 6578                        NaN                 NaN                       NaN
# 6579                        NaN                 NaN                       NaN
# 6580                        NaN                 NaN                       NaN
# 6581                        NaN                 NaN                       NaN
#
# [6092 rows x 8 columns]

# %%
summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6092 entries, 0 to 6581
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       6092 non-null   object
#  1   time                       6092 non-null   object
#  2   serv_teg_inf               6092 non-null   object
#  3   serv_teg                   6092 non-null   object
#  4   serv_mess                  6092 non-null   object
#  5   user_authenticator_number  93 non-null     float64
#  6   worker_main_number         891 non-null    float64
#  7   async_chat_thread_number   19 non-null     float64
# dtypes: float64(3), object(5)
# memory usage: 428.3+ KB

# %%
summary[['date', 'time', 'serv_teg_inf', 'serv_mess']].describe()
# Out:
#                date      time   serv_teg_inf                  serv_mess
# count          6092      6092           6092                       6092
# unique           10      1285              5                        913
# top     2023-03-04   21:13:39  Server thread   Preparing spawn area: 0%
# freq           1018       115           5003                        674

# %% [markdown]
# Достаточно ввести имя в строку ниже, чтобы получить полную информацию.

# %%
name = 'amogoos'

# %%
# vibo: найдем все упоминания игрока в сообщениях
summary[f'is_{name}'] = summary['serv_mess'].map(lambda x: name in x)
ind_name = summary[summary[f'is_{name}'] == True].index
summary[summary.index.isin(ind_name)]
# Out:
#              date      time        serv_teg_inf serv_teg  \
# 3180  2023-03-05   12:57:45       Server thread     INFO
# 3181  2023-03-05   12:58:56  User Authenticator     INFO
# 3182  2023-03-05   12:58:56       Server thread     INFO
# 3183  2023-03-05   12:58:57       Server thread     INFO
# 3184  2023-03-05   13:01:16   Async Chat Thread     INFO
# ...           ...       ...                 ...      ...
# 5101  2023-03-07   20:21:46       Server thread     INFO
# 5102  2023-03-07   20:21:46       Server thread     INFO
# 5103  2023-03-07   20:57:04       Server thread     INFO
# 5104  2023-03-07   21:02:46       Server thread     INFO
# 5105  2023-03-07   21:02:46       Server thread     INFO
#
#                                               serv_mess  \
# 3180                     Made amogoos a server operator
# 3181   UUID of player amogoos is bb8d3a15-62ea-3dd7-...
# 3182                            amogoos joined the game
# 3183                          amogoos[/[0:0:0:0:0:0:0:1
# 3184                 [Not Secure] <amogoos> amogoos red
# ...                                                 ...
# 5101                            amogoos joined the game
# 5102                          amogoos[/[0:0:0:0:0:0:0:1
# 5103   amogoos has completed the challenge [Serious ...
# 5104              amogoos lost connection: Disconnected
# 5105                              amogoos left the game
#
#       user_authenticator_number  worker_main_number  async_chat_thread_number  \
# 3180                        NaN                 NaN                       NaN
# 3181                        1.0                 NaN                       NaN
# 3182                        NaN                 NaN                       NaN
# 3183                        NaN                 NaN                       NaN
# 3184                        NaN                 NaN                       0.0
# ...                         ...                 ...                       ...
# 5101                        NaN                 NaN                       NaN
# 5102                        NaN                 NaN                       NaN
# 5103                        NaN                 NaN                       NaN
# 5104                        NaN                 NaN                       NaN
# 5105                        NaN                 NaN                       NaN
#
#       is_amogoos
# 3180        True
# 3181        True
# 3182        True
# 3183        True
# 3184        True
# ...          ...
# 5101        True
# 5102        True
# 5103        True
# 5104        True
# 5105        True
#
# [252 rows x 9 columns]
